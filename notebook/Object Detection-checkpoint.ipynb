# %%
import os,io
from google.cloud import vision
import numpy as np
import pandas as pd

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'ServiceAccountToken.json'
client = vision.ImageAnnotatorClient()

bounds = []

with io.open(os.path.join(r'D:\SiH-Frame-Project\MyVisionDemo\Images','dining_room_1.jpg'), 'rb') as image_file:
    content = image_file.read()

image = vision.types.Image(content=content)

# %%
response = client.object_localization(image=image)

# %%
response
# Out:
# localized_object_annotations {
#   mid: "/m/01mzpv"
#   name: "Chair"
#   score: 0.9172366857528687
#   bounding_poly {
#     normalized_vertices {
#       x: 0.5132526755332947
#       y: 0.6815012097358704
#     }
#     normalized_vertices {
#       x: 0.799083948135376
#       y: 0.6815012097358704
#     }
#     normalized_vertices {
#       x: 0.799083948135376
#       y: 0.9939599633216858
#     }
#     normalized_vertices {
#       x: 0.5132526755332947
#       y: 0.9939599633216858
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/019sc6"
#   name: "Lighting"
#   score: 0.9079623222351074
#   bounding_poly {
#     normalized_vertices {
#       x: 0.36881721019744873
#       y: 0.002802891656756401
#     }
#     normalized_vertices {
#       x: 0.684670627117157
#       y: 0.002802891656756401
#     }
#     normalized_vertices {
#       x: 0.684670627117157
#       y: 0.2722580134868622
#     }
#     normalized_vertices {
#       x: 0.36881721019744873
# ...

# %%
frame = pd.DataFrame(columns=['object','confidence','x1','y1','x2','y2','x3','y3','x4','y4'])

# %%
frame
# Out:
# Empty DataFrame
# Columns: [object, confidence, x1, y1, x2, y2, x3, y3, x4, y4]
# Index: []

# %%
obj_detail = list()
for loc_obj in response.localized_object_annotations:
    obj_detail.clear()
    for vertex in loc_obj.bounding_poly.normalized_vertices:
        obj_detail.append(vertex.x)
        obj_detail.append(vertex.y)
    frame = frame.append(dict(object = loc_obj.name,
                             confidence = loc_obj.score,
                             x1 = obj_detail[0],
                             y1 = obj_detail[1],
                             x2 = obj_detail[2],
                             y2 = obj_detail[3],
                             x3 = obj_detail[4],
                             y3 = obj_detail[5],
                             x4 = obj_detail[6],
                             y4 = obj_detail[7]),ignore_index=True)

# %%
frame
# Out:
#      object  confidence        x1        y1        x2        y2        x3  \
# 0     Chair    0.917237  0.513253  0.681501  0.799084  0.681501  0.799084
# 1  Lighting    0.907962  0.368817  0.002803  0.684671  0.002803  0.684671
# 2     Chair    0.877321  0.222583  0.681141  0.486803  0.681141  0.486803
# 3     Chair    0.836420  0.686870  0.642394  0.902070  0.642394  0.902070
# 4  Lighting    0.765165  0.508288  0.438748  0.562776  0.438748  0.562776
# 5     Table    0.652699  0.248833  0.597181  0.818211  0.597181  0.818211
#
#          y3        x4        y4
# 0  0.993960  0.513253  0.993960
# 1  0.272258  0.368817  0.272258
# 2  0.994341  0.222583  0.994341
# 3  0.996365  0.686870  0.996365
# 4  0.630594  0.508288  0.630594
# 5  0.981447  0.248833  0.981447

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-2c9bb440b7fb> in <module>()
# ----> 1 content.center()
#
# TypeError: center() takes at least 1 argument (0 given)
